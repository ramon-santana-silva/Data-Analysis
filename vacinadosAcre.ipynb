# %% [markdown]
# <a href="https://colab.research.google.com/https://github.com/ramon-santana-silva/Data-Analysis/edit/main/vacinadosAcre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
microdados_ac= pd.read_csv("dados_brutos_ac3/microdadosvacinacaoac3.csv", sep=";", encoding='UTF-8')
# Out:
# /tmp/ipykernel_16504/3408844160.py:1: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   microdados_ac= pd.read_csv("dados_brutos_ac3/microdadosvacinacaoac3.csv", sep=";", encoding='UTF-8')

# %%
microdados_ac.head()
# Out:
#                                  document_id  \
# 0  88755c9d-58ec-4e83-9404-2c72ac11e83d-i0b0
# 1  92ab688a-f495-41f0-8647-5dc1d9f022c5-i0b0
# 2  b02c8232-4df8-4c40-8682-167efd6bf49f-i0b0
# 3  92b8f44e-78e7-4498-9dbc-21f6de2b4a7c-i0b0
# 4  26c7ae15-0f70-4969-b481-699f484b9555-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  cc5601bdcc599dc5e5b29a0b6cb3a1718668309fe5eee5...              18
# 1  d0923d10e4393f51473498da5c289aea976a100ad187c3...              37
# 2  da5456e02df519b199b0d67b9f8a1f6a38a32a1c50ac1f...              26
# 3  9f7d6933ca26a5c66a5d0054b709885eb1b609302b5e51...              55
# 4  45054807ec71a7798cb27591691be98317364d58356a32...              16
#
#   paciente_dataNascimento paciente_enumSexoBiologico  paciente_racaCor_codigo  \
# 0              2003-08-22                          F                        4
# 1              1984-01-25                          F                        4
# ...
